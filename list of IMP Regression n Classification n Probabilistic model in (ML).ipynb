# %% [markdown]
# # Here are some common regression algorithm in machine learning

# %% [markdown]
# ![Screenshot%202024-03-29%20131848.png](attachment:Screenshot%202024-03-29%20131848.png)

# %% [markdown]
# ![Screenshot%202024-03-29%20131916.png](attachment:Screenshot%202024-03-29%20131916.png)

# %% [markdown]
# # Here are some common classification algorithm in machine learning

# %% [markdown]
# ![Screenshot%202024-03-29%20132749.png](attachment:Screenshot%202024-03-29%20132749.png)

# %% [markdown]
# ![Screenshot%202024-03-29%20132815.png](attachment:Screenshot%202024-03-29%20132815.png)

# %% [markdown]
# # Here are Two different Probabilistic model in machine learning

# %% [markdown]
# ![Screenshot%202024-03-29%20134008.png](attachment:Screenshot%202024-03-29%20134008.png)

# %% [markdown]
# ![Screenshot%202024-03-29%20134057.png](attachment:Screenshot%202024-03-29%20134057.png)

# %% [markdown]
# In summary, HMMs handle sequential data with hidden states.
# while LMMs address non-independence in data through fixed and random effects.
